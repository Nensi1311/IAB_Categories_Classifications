# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D

# %%
# Define hierarchical categories
categories = {
    "IAB1 Arts And Entertainment": ["IAB1_1_Books", "IAB1_5_Movies", "IAB1_6_Music"],
    "IAB2 Automotive": ["IAB2_11_Hatchback", "IAB2_14_MiniVan", "IAB2_15_Mororcycles", "IAB2_21_Trucks  Accessories"],
    "IAB3 Business": ["IAB3_6_Forestry"],
    "IAB17 Sports": ["IAB17_5_Boxing", "IAB17_6_CanoeING", "IAB17_7_Cheerleading", "IAB17_9_Cricket", "IAB17_11_Fly Fishing", "IAB17_12_Football", "IAB17_15_Golf", "IAB17_16_Horse Racing", "IAB17_29_Rugby", "IAB17_31_SailING", "IAB17_36_Snowboarding", "IAB17_37_Surfing", "IAB17_38_Swimming", "IAB17_39_Table Tennis", "IAB17_40_Tennis", "IAB17_41_Volleyball"]
}

# %%
# Data directories
train_dir = "/LAB/SGP-II/Dataset/train"
test_dir = "/LAB/SGP-II/Dataset/test"
val_dir = "/LAB/SGP-II/Dataset/val"

# %%
# Image dimensions
IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 32

# Learning rate
LEARNING_RATE = 0.001

# %%
# Data Generators
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=1,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 2313 images belonging to 24 classes.
# Found 280 images belonging to 24 classes.
# Found 311 images belonging to 24 classes.

# %%
# Load pre-trained MobileNetV2 model
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3))

# Add custom layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(len(train_generator.class_indices), activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=outputs)

# Freeze base model layers
for layer in base_model.layers:
    layer.trainable = False
# Out:
# 2024-12-20 16:52:58.565729: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 223 MB memory:  -> device: 0, name: NVIDIA RTX A5000, pci bus id: 0000:3b:00.0, compute capability: 8.6
# 2024-12-20 16:52:58.567600: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 21789 MB memory:  -> device: 1, name: NVIDIA RTX A5000, pci bus id: 0000:af:00.0, compute capability: 8.6
# 2024-12-20 16:52:58.576451: I tensorflow/stream_executor/cuda/cuda_driver.cc:732] failed to allocate 223.88M (234749952 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory

# %%
# Compile the model
optimizer = tf.keras.optimizers.SGD(learning_rate=LEARNING_RATE)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
with tf.device("/GPU:1"):
    history = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=100
    )
# Out:
# 2024-12-20 16:53:06.799479: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2024-12-20 16:53:09.665393: I tensorflow/stream_executor/cuda/cuda_dnn.cc:381] Loaded cuDNN version 8204
#  4/73 [>.............................] - ETA: 3s - loss: 3.4911 - accuracy: 0.0625
# 2024-12-20 16:53:12.009945: I tensorflow/stream_executor/cuda/cuda_blas.cc:1760] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 73/73 [==============================] - 11s 87ms/step - loss: 3.3215 - accuracy: 0.0610 - val_loss: 3.1965 - val_accuracy: 0.0821
# Epoch 2/100
# 73/73 [==============================] - 6s 75ms/step - loss: 3.0321 - accuracy: 0.1206 - val_loss: 2.9681 - val_accuracy: 0.1500
# Epoch 3/100
# 73/73 [==============================] - 6s 78ms/step - loss: 2.8057 - accuracy: 0.1898 - val_loss: 2.7726 - val_accuracy: 0.2321
# Epoch 4/100
# 73/73 [==============================] - 5s 75ms/step - loss: 2.6011 - accuracy: 0.2905 - val_loss: 2.5907 - val_accuracy: 0.3143
# Epoch 5/100
# 73/73 [==============================] - 6s 77ms/step - loss: 2.4110 - accuracy: 0.3926 - val_loss: 2.4168 - val_accuracy: 0.3857
# Epoch 6/100
# 73/73 [==============================] - 6s 75ms/step - loss: 2.2275 - accuracy: 0.4773 - val_loss: 2.2497 - val_accuracy: 0.4643
# Epoch 7/100
# 73/73 [==============================] - 5s 74ms/step - loss: 2.0535 - accuracy: 0.5387 - val_loss: 2.0895 - val_accuracy: 0.5000
# Epoch 8/100
# 73/73 [==============================] - 6s 80ms/step - loss: 1.8869 - accuracy: 0.6048 - val_loss: 1.9385 - val_accuracy: 0.5714
# Epoch 9/100
# 73/73 [==============================] - 6s 76ms/step - loss: 1.7320 - accuracy: 0.6610 - val_loss: 1.7977 - val_accuracy: 0.6107
# Epoch 10/100
# 73/73 [==============================] - 6s 79ms/step - loss: 1.5899 - accuracy: 0.7008 - val_loss: 1.6683 - val_accuracy: 0.6429
# Epoch 11/100
# 73/73 [==============================] - 6s 79ms/step - loss: 1.4587 - accuracy: 0.7406 - val_loss: 1.5492 - val_accuracy: 0.6714
# Epoch 12/100
# 73/73 [==============================] - 6s 79ms/step - loss: 1.3408 - accuracy: 0.7748 - val_loss: 1.4421 - val_accuracy: 0.6964
# Epoch 13/100
# 73/73 [==============================] - 6s 75ms/step - loss: 1.2342 - accuracy: 0.7981 - val_loss: 1.3452 - val_accuracy: 0.7286
# Epoch 14/100
# 73/73 [==============================] - 6s 77ms/step - loss: 1.1392 - accuracy: 0.8214 - val_loss: 1.2596 - val_accuracy: 0.7429
# Epoch 15/100
# 73/73 [==============================] - 6s 76ms/step - loss: 1.0542 - accuracy: 0.8366 - val_loss: 1.1823 - val_accuracy: 0.7500
# Epoch 16/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.9788 - accuracy: 0.8470 - val_loss: 1.1130 - val_accuracy: 0.7571
# Epoch 17/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.9110 - accuracy: 0.8578 - val_loss: 1.0504 - val_accuracy: 0.7714
# Epoch 18/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.8517 - accuracy: 0.8686 - val_loss: 0.9959 - val_accuracy: 0.7857
# Epoch 19/100
# 73/73 [==============================] - 6s 79ms/step - loss: 0.7981 - accuracy: 0.8820 - val_loss: 0.9473 - val_accuracy: 0.7964
# Epoch 20/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.7508 - accuracy: 0.8846 - val_loss: 0.9024 - val_accuracy: 0.8107
# Epoch 21/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.7080 - accuracy: 0.8936 - val_loss: 0.8638 - val_accuracy: 0.8143
# Epoch 22/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.6700 - accuracy: 0.8997 - val_loss: 0.8279 - val_accuracy: 0.8214
# Epoch 23/100
# 73/73 [==============================] - 6s 78ms/step - loss: 0.6356 - accuracy: 0.9036 - val_loss: 0.7961 - val_accuracy: 0.8214
# Epoch 24/100
# 73/73 [==============================] - 6s 79ms/step - loss: 0.6046 - accuracy: 0.9049 - val_loss: 0.7668 - val_accuracy: 0.8214
# Epoch 25/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.5762 - accuracy: 0.9127 - val_loss: 0.7403 - val_accuracy: 0.8214
# Epoch 26/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.5509 - accuracy: 0.9144 - val_loss: 0.7157 - val_accuracy: 0.8286
# Epoch 27/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.5273 - accuracy: 0.9183 - val_loss: 0.6935 - val_accuracy: 0.8286
# Epoch 28/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.5057 - accuracy: 0.9213 - val_loss: 0.6729 - val_accuracy: 0.8393
# Epoch 29/100
# 73/73 [==============================] - 6s 75ms/step - loss: 0.4858 - accuracy: 0.9230 - val_loss: 0.6540 - val_accuracy: 0.8393
# Epoch 30/100
# 73/73 [==============================] - 6s 75ms/step - loss: 0.4678 - accuracy: 0.9239 - val_loss: 0.6367 - val_accuracy: 0.8429
# Epoch 31/100
# 73/73 [==============================] - 6s 79ms/step - loss: 0.4509 - accuracy: 0.9265 - val_loss: 0.6206 - val_accuracy: 0.8500
# Epoch 32/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.4351 - accuracy: 0.9304 - val_loss: 0.6057 - val_accuracy: 0.8536
# Epoch 33/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.4206 - accuracy: 0.9304 - val_loss: 0.5912 - val_accuracy: 0.8571
# Epoch 34/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.4067 - accuracy: 0.9343 - val_loss: 0.5775 - val_accuracy: 0.8607
# Epoch 35/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.3941 - accuracy: 0.9360 - val_loss: 0.5648 - val_accuracy: 0.8679
# Epoch 36/100
# 73/73 [==============================] - 5s 75ms/step - loss: 0.3822 - accuracy: 0.9382 - val_loss: 0.5528 - val_accuracy: 0.8679
# Epoch 37/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.3710 - accuracy: 0.9425 - val_loss: 0.5416 - val_accuracy: 0.8679
# Epoch 38/100
# 73/73 [==============================] - 6s 75ms/step - loss: 0.3604 - accuracy: 0.9421 - val_loss: 0.5314 - val_accuracy: 0.8643
# Epoch 39/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.3504 - accuracy: 0.9447 - val_loss: 0.5209 - val_accuracy: 0.8714
# Epoch 40/100
# 73/73 [==============================] - 6s 78ms/step - loss: 0.3410 - accuracy: 0.9451 - val_loss: 0.5120 - val_accuracy: 0.8679
# Epoch 41/100
# 73/73 [==============================] - 6s 79ms/step - loss: 0.3323 - accuracy: 0.9455 - val_loss: 0.5032 - val_accuracy: 0.8679
# Epoch 42/100
# 73/73 [==============================] - 6s 80ms/step - loss: 0.3237 - accuracy: 0.9473 - val_loss: 0.4948 - val_accuracy: 0.8750
# Epoch 43/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.3156 - accuracy: 0.9490 - val_loss: 0.4866 - val_accuracy: 0.8714
# Epoch 44/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.3080 - accuracy: 0.9494 - val_loss: 0.4791 - val_accuracy: 0.8750
# Epoch 45/100
# 73/73 [==============================] - 6s 78ms/step - loss: 0.3008 - accuracy: 0.9498 - val_loss: 0.4725 - val_accuracy: 0.8750
# Epoch 46/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.2938 - accuracy: 0.9511 - val_loss: 0.4657 - val_accuracy: 0.8821
# Epoch 47/100
# 73/73 [==============================] - 5s 75ms/step - loss: 0.2873 - accuracy: 0.9542 - val_loss: 0.4595 - val_accuracy: 0.8786
# Epoch 48/100
# 73/73 [==============================] - 6s 78ms/step - loss: 0.2810 - accuracy: 0.9533 - val_loss: 0.4534 - val_accuracy: 0.8821
# Epoch 49/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.2749 - accuracy: 0.9563 - val_loss: 0.4469 - val_accuracy: 0.8857
# Epoch 50/100
# 73/73 [==============================] - 6s 75ms/step - loss: 0.2691 - accuracy: 0.9563 - val_loss: 0.4419 - val_accuracy: 0.8857
# Epoch 51/100
# 73/73 [==============================] - 6s 78ms/step - loss: 0.2634 - accuracy: 0.9598 - val_loss: 0.4370 - val_accuracy: 0.8857
# Epoch 52/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.2581 - accuracy: 0.9598 - val_loss: 0.4312 - val_accuracy: 0.8857
# Epoch 53/100
# 73/73 [==============================] - 5s 75ms/step - loss: 0.2530 - accuracy: 0.9611 - val_loss: 0.4260 - val_accuracy: 0.8857
# Epoch 54/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.2482 - accuracy: 0.9620 - val_loss: 0.4213 - val_accuracy: 0.8857
# Epoch 55/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.2435 - accuracy: 0.9628 - val_loss: 0.4166 - val_accuracy: 0.8857
# Epoch 56/100
# 73/73 [==============================] - 6s 79ms/step - loss: 0.2387 - accuracy: 0.9650 - val_loss: 0.4124 - val_accuracy: 0.8857
# Epoch 57/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.2345 - accuracy: 0.9654 - val_loss: 0.4081 - val_accuracy: 0.8857
# Epoch 58/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.2303 - accuracy: 0.9667 - val_loss: 0.4039 - val_accuracy: 0.8857
# Epoch 59/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.2262 - accuracy: 0.9671 - val_loss: 0.4005 - val_accuracy: 0.8929
# Epoch 60/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.2222 - accuracy: 0.9684 - val_loss: 0.3966 - val_accuracy: 0.8929
# Epoch 61/100
# 73/73 [==============================] - 6s 78ms/step - loss: 0.2184 - accuracy: 0.9689 - val_loss: 0.3928 - val_accuracy: 0.8929
# Epoch 62/100
# 73/73 [==============================] - 6s 78ms/step - loss: 0.2146 - accuracy: 0.9702 - val_loss: 0.3888 - val_accuracy: 0.8929
# Epoch 63/100
# 73/73 [==============================] - 6s 78ms/step - loss: 0.2110 - accuracy: 0.9702 - val_loss: 0.3853 - val_accuracy: 0.8893
# Epoch 64/100
# 73/73 [==============================] - 6s 79ms/step - loss: 0.2076 - accuracy: 0.9706 - val_loss: 0.3824 - val_accuracy: 0.8929
# Epoch 65/100
# 73/73 [==============================] - 6s 78ms/step - loss: 0.2042 - accuracy: 0.9715 - val_loss: 0.3795 - val_accuracy: 0.8929
# Epoch 66/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.2009 - accuracy: 0.9715 - val_loss: 0.3762 - val_accuracy: 0.8929
# Epoch 67/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.1978 - accuracy: 0.9736 - val_loss: 0.3728 - val_accuracy: 0.8929
# Epoch 68/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.1948 - accuracy: 0.9728 - val_loss: 0.3698 - val_accuracy: 0.8964
# Epoch 69/100
# 73/73 [==============================] - 6s 79ms/step - loss: 0.1917 - accuracy: 0.9749 - val_loss: 0.3666 - val_accuracy: 0.9000
# Epoch 70/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.1888 - accuracy: 0.9741 - val_loss: 0.3635 - val_accuracy: 0.9000
# Epoch 71/100
# 73/73 [==============================] - 5s 75ms/step - loss: 0.1859 - accuracy: 0.9741 - val_loss: 0.3611 - val_accuracy: 0.9000
# Epoch 72/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.1831 - accuracy: 0.9749 - val_loss: 0.3583 - val_accuracy: 0.9000
# Epoch 73/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.1805 - accuracy: 0.9758 - val_loss: 0.3557 - val_accuracy: 0.9000
# Epoch 74/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.1780 - accuracy: 0.9754 - val_loss: 0.3537 - val_accuracy: 0.9000
# Epoch 75/100
# 73/73 [==============================] - 6s 82ms/step - loss: 0.1754 - accuracy: 0.9762 - val_loss: 0.3513 - val_accuracy: 0.9000
# Epoch 76/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.1730 - accuracy: 0.9767 - val_loss: 0.3489 - val_accuracy: 0.9036
# Epoch 77/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.1706 - accuracy: 0.9775 - val_loss: 0.3466 - val_accuracy: 0.9036
# Epoch 78/100
# 73/73 [==============================] - 5s 74ms/step - loss: 0.1683 - accuracy: 0.9771 - val_loss: 0.3444 - val_accuracy: 0.9036
# Epoch 79/100
# 73/73 [==============================] - 6s 75ms/step - loss: 0.1661 - accuracy: 0.9780 - val_loss: 0.3423 - val_accuracy: 0.9036
# Epoch 80/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.1638 - accuracy: 0.9784 - val_loss: 0.3400 - val_accuracy: 0.9036
# Epoch 81/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.1617 - accuracy: 0.9788 - val_loss: 0.3382 - val_accuracy: 0.9036
# Epoch 82/100
# 73/73 [==============================] - 5s 74ms/step - loss: 0.1595 - accuracy: 0.9788 - val_loss: 0.3356 - val_accuracy: 0.9071
# Epoch 83/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.1575 - accuracy: 0.9784 - val_loss: 0.3337 - val_accuracy: 0.9071
# Epoch 84/100
# 73/73 [==============================] - 5s 75ms/step - loss: 0.1554 - accuracy: 0.9788 - val_loss: 0.3316 - val_accuracy: 0.9107
# Epoch 85/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.1534 - accuracy: 0.9797 - val_loss: 0.3302 - val_accuracy: 0.9107
# Epoch 86/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.1514 - accuracy: 0.9797 - val_loss: 0.3288 - val_accuracy: 0.9107
# Epoch 87/100
# 73/73 [==============================] - 6s 78ms/step - loss: 0.1496 - accuracy: 0.9801 - val_loss: 0.3269 - val_accuracy: 0.9107
# Epoch 88/100
# 73/73 [==============================] - 6s 78ms/step - loss: 0.1478 - accuracy: 0.9810 - val_loss: 0.3252 - val_accuracy: 0.9107
# Epoch 89/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.1460 - accuracy: 0.9805 - val_loss: 0.3229 - val_accuracy: 0.9107
# Epoch 90/100
# 73/73 [==============================] - 6s 78ms/step - loss: 0.1442 - accuracy: 0.9805 - val_loss: 0.3211 - val_accuracy: 0.9107
# Epoch 91/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.1425 - accuracy: 0.9814 - val_loss: 0.3193 - val_accuracy: 0.9107
# Epoch 92/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.1408 - accuracy: 0.9805 - val_loss: 0.3177 - val_accuracy: 0.9107
# Epoch 93/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.1391 - accuracy: 0.9814 - val_loss: 0.3163 - val_accuracy: 0.9107
# Epoch 94/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.1375 - accuracy: 0.9818 - val_loss: 0.3148 - val_accuracy: 0.9107
# Epoch 95/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.1359 - accuracy: 0.9818 - val_loss: 0.3131 - val_accuracy: 0.9107
# Epoch 96/100
# 73/73 [==============================] - 6s 76ms/step - loss: 0.1344 - accuracy: 0.9823 - val_loss: 0.3115 - val_accuracy: 0.9107
# Epoch 97/100
# 73/73 [==============================] - 6s 78ms/step - loss: 0.1329 - accuracy: 0.9818 - val_loss: 0.3103 - val_accuracy: 0.9107
# Epoch 98/100
# 73/73 [==============================] - 6s 79ms/step - loss: 0.1314 - accuracy: 0.9827 - val_loss: 0.3088 - val_accuracy: 0.9107
# Epoch 99/100
# 73/73 [==============================] - 6s 77ms/step - loss: 0.1300 - accuracy: 0.9823 - val_loss: 0.3076 - val_accuracy: 0.9107
# Epoch 100/100
# 73/73 [==============================] - 6s 78ms/step - loss: 0.1285 - accuracy: 0.9827 - val_loss: 0.3063 - val_accuracy: 0.9107

# %%
# Evaluate the model
with tf.device("/GPU:1"):
    test_loss, test_accuracy = model.evaluate(test_generator)
    print(f"Test Accuracy: {test_accuracy}")
# Out:
# 311/311 [==============================] - 3s 9ms/step - loss: 0.2860 - accuracy: 0.9132
# Test Accuracy: 0.9131832718849182

# %%
# Plot loss and accuracy
def plot_metrics(history):
    plt.figure(figsize=(12, 6))

    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss Over Epochs')
    plt.legend()

    # Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Accuracy Over Epochs')
    plt.legend()

    plt.show()

plot_metrics(history)

# %%
# Confusion matrix and classification report
with tf.device("/GPU:1"):
    predictions = model.predict(test_generator)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = test_generator.classes
    class_labels = list(test_generator.class_indices.keys())

    conf_matrix = confusion_matrix(true_classes, predicted_classes)

    plt.figure(figsize=(10, 8))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()

# %%
with tf.device("/GPU:1"):
    print("Classification Report:")
    print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
# Classification Report:
#                              precision    recall  f1-score   support
#
#        IAB17_11_Fly Fishing       0.88      1.00      0.93        14
#           IAB17_12_Football       0.91      0.71      0.80        14
#               IAB17_15_Golf       0.79      0.85      0.81        13
#       IAB17_16_Horse Racing       1.00      1.00      1.00        13
#              IAB17_29_Rugby       0.93      1.00      0.96        13
#            IAB17_31_SailING       1.00      1.00      1.00        13
#       IAB17_36_Snowboarding       0.93      1.00      0.96        13
#            IAB17_37_Surfing       0.93      1.00      0.96        13
#           IAB17_38_Swimming       1.00      0.92      0.96        13
#       IAB17_39_Table Tennis       1.00      0.85      0.92        13
#             IAB17_40_Tennis       0.85      0.85      0.85        13
#         IAB17_41_Volleyball       1.00      0.93      0.96        14
#              IAB17_5_Boxing       0.93      1.00      0.96        13
#            IAB17_6_CanoeING       1.00      1.00      1.00        13
#        IAB17_7_Cheerleading       0.76      1.00      0.87        13
#             IAB17_9_Cricket       0.91      0.77      0.83        13
#                IAB1_1_Books       0.75      0.86      0.80        14
#               IAB1_5_Movies       0.75      0.46      0.57        13
#                IAB1_6_Music       0.93      1.00      0.96        13
#           IAB2_11_Hatchback       0.92      1.00      0.96        12
#             IAB2_14_MiniVan       1.00      0.85      0.92        13
#         IAB2_15_Mororcycles       0.91      0.91      0.91        11
# IAB2_21_Trucks  Accessories       1.00      1.00      1.00        12
#             IAB3_6_Forestry       0.92      1.00      0.96        12
#
#                    accuracy                           0.91       311
#                   macro avg       0.92      0.91      0.91       311
#                weighted avg       0.92      0.91      0.91       311

# %%
# Predict a single image
with tf.device("/GPU:1"):
    def classify_image(image_path, model, categories):
        image = cv2.imread(image_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image_resized = cv2.resize(image, (IMG_WIDTH, IMG_HEIGHT))
        image_processed = preprocess_input(image_resized)
        image_processed = np.expand_dims(image_processed, axis=0)

        prediction = model.predict(image_processed)
        predicted_class_index = np.argmax(prediction)
        predicted_class = class_labels[predicted_class_index]

        parent_category = None
        for parent, subcategories in categories.items():
            if predicted_class in subcategories:
                parent_category = parent
                break

        plt.imshow(image_rgb)
        plt.title(f"Sub Category: {predicted_class}, Main Category: {parent_category}")
        plt.axis('off')
        plt.show()

        print(f"Sub Category: {predicted_class}")
        print(f"Main Category: {parent_category}")

    # Example usage
    image_path = "/LAB/SGP-II/Dataset/test/IAB3_6_Forestry/0OPLB3CCKO24.jpg"
    classify_image(image_path, model, categories)
# Out:
# Sub Category: IAB3_6_Forestry
# Main Category: IAB3 Business
